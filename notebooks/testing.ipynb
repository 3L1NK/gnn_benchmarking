# %%
# !ls
# Out:
# 27Okt25_GNN_xgboost.ipynb GNN Xgboost Oct 27.ipynb
# Base_notebook.ipynb       testing.ipynb

# %%
# !cd ..

# %%
import pandas as pd

df = pd.read_parquet("../data/processed/prices.parquet")

print("Rows:", len(df))
print("Columns:", df.columns.tolist())

print("\nMissing values per column:")
print(df.isna().sum())

print("\nMissing values percentage:")
print((df.isna().mean() * 100).round(2))
# Out:
# Rows: 194426
# Columns: ['date', 'ticker', 'close', 'volume', 'ret_1d', 'ret_5d', 'ret_20d', 'log_ret_1d', 'vol_20d', 'ema_10', 'ema_20', 'mom_10', 'rsi_14', 'macd_line', 'macd_signal', 'macd_hist', 'vol_z_20']
#
# Missing values per column:
# date             0
# ticker           0
# close            0
# volume           0
# ret_1d          32
# ret_5d         160
# ret_20d        640
# log_ret_1d      32
# vol_20d        640
# ema_10           0
# ema_20           0
# mom_10         320
# rsi_14         448
# macd_line        0
# macd_signal      0
# macd_hist        0
# vol_z_20       608
# dtype: int64
#
# Missing values percentage:
# date           0.00
# ticker         0.00
# close          0.00
# volume         0.00
# ret_1d         0.02
# ret_5d         0.08
# ret_20d        0.33
# log_ret_1d     0.02
# vol_20d        0.33
# ema_10         0.00
# ema_20         0.00
# mom_10         0.16
# rsi_14         0.23
# macd_line      0.00
# macd_signal    0.00
# macd_hist      0.00
# vol_z_20       0.31
# dtype: float64
